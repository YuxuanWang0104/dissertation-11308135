# %%
source("/Users/wyx/Desktop/dissertation/wholecode.R")

# %%
experiments_sample_size <- list(
  list(name = "N: 1000", sample_size = 1000),
  list(name = "N: 2000", sample_size = 2000),
  list(name = "N: 3000", sample_size = 3000),
  list(name = "N: 4000", sample_size = 4000),
  list(name = "N: 5000", sample_size = 5000),
  list(name = "N: 6000", sample_size = 6000),
  list(name = "N: 7000", sample_size = 7000),
  list(name = "N: 8000", sample_size = 8000),
  list(name = "N: 9000", sample_size = 9000),
  list(name = "N: 10000", sample_size = 10000),
  list(name = "N: 11000", sample_size = 11000),
  list(name = "N: 12000", sample_size = 12000),
  list(name = "N: 13000", sample_size = 13000),
  list(name = "N: 14000", sample_size = 14000),
  list(name = "N: 15000", sample_size = 15000),
  list(name = "N: 16000", sample_size = 16000),
  list(name = "N: 17000", sample_size = 17000),
  list(name = "N: 18000", sample_size = 18000),
  list(name = "N: 19000", sample_size = 19000),
  list(name = "N: 20000", sample_size = 20000)
)

# %% [markdown]
# # 1) Predictor-Outcome Association Shift

# %%
generate_shifted_age_data <- function(seed, sample_size) {
  set.seed(seed)
  data <- generate_shifted_data_age(
    time_periods = 2,
    n = sample_size,
    target_mortality_rate = 0.2,
    age_mean = 64.6,
    age_sd = 12.5,
    sex_prob = 0.309,
    cpd_prob = 0.107,
    pcs_prob = 0.282,
    cps_prob = 0.241, 
    beta_age_start = 0.0285181,
    beta_age_end = 0.0666354,
    beta_sex = 0.2196434,
    beta_cpd = 0.1886564,
    beta_pcs = 1.118599,
    beta_cps = 1.086517
  )
  return(data)
}

# %%
# 初始化结果数据框
total_results_adjust_ss_1 <- data.frame()

# 运行实验
set.seed(123)
num_simulations <- 200

for (exp in experiments_sample_size) {
  results <- data.frame(auc = numeric(num_simulations), o_e = numeric(num_simulations), c_slope = numeric(num_simulations), brier_score = numeric(num_simulations))
  
  for (i in 1:num_simulations) {
    set.seed(i)
    
    data_train <- generate_shifted_age_data(i, exp$sample_size)
    
    # 训练模型
    model <- train_model(data_train)
      
    # 计算性能指标
    metrics <- calculate_performance_metrics(model)
    
    results[i, ] <- unlist(metrics)
  }
  
  # 计算中位数和四分位数性能指标
  median_metrics <- apply(results, 2, median)
  quantile_metrics_25 <- apply(results, 2, quantile, probs = 0.25)
  quantile_metrics_75 <- apply(results, 2, quantile, probs = 0.75)
  
    
  # 格式化结果并保留小数点后7位
  formatted_metrics <- data.frame(
    experiment = exp$name,
    auc_median = median_metrics['auc'],
    auc_25 = quantile_metrics_25['auc'],
    auc_75 = quantile_metrics_75['auc'],
    o_e_median = median_metrics['o_e'],
    o_e_25 = quantile_metrics_25['o_e'],
    o_e_75 = quantile_metrics_75['o_e'],
    c_slope_median = median_metrics['c_slope'],
    c_slope_25 = quantile_metrics_25['c_slope'],
    c_slope_75 = quantile_metrics_75['c_slope'],
    brier_score_median = median_metrics['brier_score'],
    brier_score_25 = quantile_metrics_25['brier_score'],
    brier_score_75 = quantile_metrics_75['brier_score']
  )
  
  total_results_adjust_ss_1 <- rbind(total_results_adjust_ss_1, formatted_metrics)
  
  total_results_adjust_ss_1
}
# Out:
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# ...
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < c
# auc19 0.9059576      0.8890407  0.9220021  0.1440063          0.1438786
#       brier_score_75
# auc   0.1457448
# auc1  0.1448581
# auc2  0.1446515
# auc3  0.1445224
# auc4  0.1444880
# auc5  0.1443954
# auc6  0.1443648
# auc7  0.1442802
# auc8  0.1442849
# auc9  0.1442633
# auc10 0.1442043
# auc11 0.1441711
# auc12 0.1441606
# auc13 0.1441838
# auc14 0.1441523
# auc15 0.1441174
# auc16 0.1441502
# auc17 0.1441213
# auc18 0.1441043
# auc19 0.1441207

# %%
# 设置图像输出宽度
options(repr.plot.width = 8, repr.plot.height = 8)
create_error_bar_plots(total_results_adjust_ss_1, "adjust sample size for predictor-outcome association shift")
# Out:
# plot without title
# plot without title
# plot without title
# plot without title

# %% [markdown]
# # 2) event rate shift

# %%
# 定义 generate_gradual_shifted_data 函数
generate_event_rate_shifted_data_1 <- function(seed, sample_size, target_mortality_start, target_mortality_end) {
  set.seed(seed)
  data <- generate_event_rate_shifted_data(
    time_periods = 2,
    n = sample_size,
    target_mortality_start = target_mortality_start,
    target_mortality_end = target_mortality_end,
    age_mean = 64.6,
    age_sd = 12.5,
    sex_prob = 0.309,
    cpd_prob = 0.107,
    pcs_prob = 0.282,
    cps_prob = 0.241, 
    beta_age = 0.0285181, 
    beta_cps = 1.086517,
    beta_sex = 0.2196434,
    beta_cpd = 0.1886564,
    beta_pcs = 1.118599
  )
  return(data)
}

# %%
# 初始化结果数据框
total_results_adjust_ss_2 <- data.frame()

# 运行实验
set.seed(123)
num_simulations <- 200

for (exp in experiments_sample_size) {
  results <- data.frame(auc = numeric(num_simulations), o_e = numeric(num_simulations), c_slope = numeric(num_simulations), brier_score = numeric(num_simulations))
  
  for (i in 1:num_simulations) {
    set.seed(i)
    
    data_train <- generate_event_rate_shifted_data_1(i,exp$sample_size, 0.2,0.25)
    
    # 训练模型
    model <- train_model(data_train)
      
    # 计算性能指标
    metrics <- calculate_performance_metrics(model)
    
    results[i, ] <- unlist(metrics)
  }
  
  # 计算中位数和四分位数性能指标
  median_metrics <- apply(results, 2, median)
  quantile_metrics_25 <- apply(results, 2, quantile, probs = 0.25)
  quantile_metrics_75 <- apply(results, 2, quantile, probs = 0.75)
  
    
  # 格式化结果并保留小数点后7位
  formatted_metrics <- data.frame(
    experiment = exp$name,
    auc_median = median_metrics['auc'],
    auc_25 = quantile_metrics_25['auc'],
    auc_75 = quantile_metrics_75['auc'],
    o_e_median = median_metrics['o_e'],
    o_e_25 = quantile_metrics_25['o_e'],
    o_e_75 = quantile_metrics_75['o_e'],
    c_slope_median = median_metrics['c_slope'],
    c_slope_25 = quantile_metrics_25['c_slope'],
    c_slope_75 = quantile_metrics_75['c_slope'],
    brier_score_median = median_metrics['brier_score'],
    brier_score_25 = quantile_metrics_25['brier_score'],
    brier_score_75 = quantile_metrics_75['brier_score']
  )
  
  total_results_adjust_ss_2  <- rbind(total_results_adjust_ss_2 , formatted_metrics)
}
# Out:
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# ...
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases

# %%
total_results_adjust_ss_2
# Out:
#       experiment auc_median auc_25    auc_75    o_e_median o_e_25    o_e_75
# auc   N: 1000    0.7231850  0.7212185 0.7246369 0.8850824  0.8495114 0.9198313
# auc1  N: 2000    0.7243123  0.7231957 0.7252222 0.8965245  0.8688062 0.9211333
# auc2  N: 3000    0.7250488  0.7242032 0.7255153 0.8907887  0.8665484 0.9163878

# Out:
# plot without title
# plot without title
# plot without title
# plot without title

# %% [markdown]
# # 3) case-mix shift

# %%
generate_covariate_shifted_data_age_2 <- function(seed, sample_size, age_mean_start, age_mean_end) {
  set.seed(seed)
  data <- generate_covariate_shifted_data_age(
    time_periods = 2,
    n = sample_size,
    target_mortality_rate = 0.2,
    age_mean_start = age_mean_start,
    age_mean_end = age_mean_end,
    age_sd = 12.5,
    sex_prob = 0.309,
    cpd_prob = 0.107,
    pcs_prob = 0.282,
    cps_prob = 0.241, 
    beta_age = 0.0285181,
    beta_sex = 0.2196434,
    beta_cpd = 0.1886564,
    beta_pcs = 1.118599,
    beta_cps = 1.086517
  )
  return(data)
}

# %%
# 初始化结果数据框
total_results_adjust_ss_3 <- data.frame()

# 运行实验
set.seed(123)
num_simulations <- 200

for (exp in experiments_sample_size) {
  results <- data.frame(auc = numeric(num_simulations), o_e = numeric(num_simulations), c_slope = numeric(num_simulations), brier_score = numeric(num_simulations))
  
  for (i in 1:num_simulations) {
    set.seed(i)
    
    data_train <- generate_covariate_shifted_data_age_2(i,exp$sample_size,64.6,62.5)
    
    # 训练模型
    model <- train_model(data_train)
      
    # 计算性能指标
    metrics <- calculate_performance_metrics(model)
    
    results[i, ] <- unlist(metrics)
  }
  
  # 计算中位数和四分位数性能指标
  median_metrics <- apply(results, 2, median)
  quantile_metrics_25 <- apply(results, 2, quantile, probs = 0.25)
  quantile_metrics_75 <- apply(results, 2, quantile, probs = 0.75)
  
    
  # 格式化结果并保留小数点后7位
  formatted_metrics <- data.frame(
    experiment = exp$name,
    auc_median = median_metrics['auc'],
    auc_25 = quantile_metrics_25['auc'],
    auc_75 = quantile_metrics_75['auc'],
    o_e_median = median_metrics['o_e'],
    o_e_25 = quantile_metrics_25['o_e'],
    o_e_75 = quantile_metrics_75['o_e'],
    c_slope_median = median_metrics['c_slope'],
    c_slope_25 = quantile_metrics_25['c_slope'],
    c_slope_75 = quantile_metrics_75['c_slope'],
    brier_score_median = median_metrics['brier_score'],
    brier_score_25 = quantile_metrics_25['brier_score'],
    brier_score_75 = quantile_metrics_75['brier_score']
  )
  
  total_results_adjust_ss_3  <- rbind(total_results_adjust_ss_3 , formatted_metrics)
}
# Out:
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# ...
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases

# %%
total_results_adjust_ss_3
# Out:
#       experiment auc_median auc_25    auc_75    o_e_median o_e_25    o_e_75
# auc   N: 1000    0.7229533  0.7208750 0.7247001 0.9770703  0.9335271 1.0195424
# auc1  N: 2000    0.7243460  0.7234582 0.7251001 0.9816283  0.9540640 1.0116022
# auc2  N: 3000    0.7248435  0.7241980 0.7254025 0.9763880  0.9483565 1.0032715
# auc3  N: 4000    0.7252066  0.7244627 0.7257085 0.9907797  0.9657129 1.0099618
# auc4  N: 5000    0.7252623  0.7245827 0.7256268 0.9799206  0.9602766 0.9994477
# auc5  N: 6000    0.7253386  0.7248065 0.7257755 0.9858991  0.9651686 1.0033968
# auc6  N: 7000    0.7254355  0.7249960 0.7257627 0.9843773  0.9665883 1.0008682
# auc7  N: 8000    0.7254383  0.7250058 0.7257541 0.9809727  0.9631411 0.9967799
# auc8  N: 9000    0.7254902  0.7251232 0.7258049 0.9827229  0.9687420 0.9978045
# auc9  N: 10000   0.7255414  0.7252016 0.7257989 0.9845135  0.9694907 0.9969285
# auc10 N: 11000   0.7255607  0.7252444 0.7258445 0.9843574  0.9697207 0.9968247
# auc11 N: 12000   0.7255713  0.7252827 0.7258197 0.9826181  0.9665591 0.9959589
# auc12 N: 13000   0.7255620  0.7251933 0.7258013 0.9836900  0.9721898 0.9980158
# auc13 N: 14000   0.7255655  0.7252822 0.7258589 0.9832926  0.9742693 0.9952838
# auc14 N: 15000   0.7255878  0.7252655 0.7258385 0.9867637  0.9751300 0.9986601
# auc15 N: 16000   0.7256336  0.7253869 0.7258491 0.9817607  0.9712724 0.9951231
# auc16 N: 17000   0.7255765  0.7253291 0.7258321 0.9843537  0.9742370 0.9941424
# auc17 N: 18000   0.7255796  0.7253492 0.7258122 0.9839514  0.9723988 0.9952574
# auc18 N: 19000   0.7256370  0.7254020 0.7258617 0.9857638  0.9744877 0.9947889
# auc19 N: 20000   0.7255937  0.7253972 0.7258146 0.9845689  0.9738336 0.9942347
#       c_slope_median c_slope_25 c_slope_75 brier_score_median brier_score_25
# auc   1.029605       0.9734306  1.102159   0.1439722          0.1435488
# auc1  1.033714       0.9912748  1.101467   0.1434369          0.1432807
# auc2  1.048186       1.0036786  1.089523   0.1433549          0.1431922
# auc3  1.054219       1.0155440  1.092136   0.1432525          0.1431288
# auc4  1.063734       1.0243114  1.092082   0.1432179          0.1431091
# auc5  1.054291       1.0308986  1.095652   0.1431584          0.1430746
# auc6  1.059761       1.0346816  1.089907   0.1431479          0.1430711
# auc7  1.062714       1.0375477  1.090733   0.1431560          0.1430679
# auc8  1.059873       1.0358291  1.082386   0.1430887          0.1430335
# auc9  1.064743       1.0441964  1.084300   0.1431047          0.1430270
# auc10 1.062871       1.0418982  1.088487   0.1431015          0.1430349
# auc11 1.060955       1.0418938  1.085667   0.1430909          0.1430260
# auc12 1.065760       1.0468873  1.089247   0.1430859          0.1430298
# auc13 1.062376       1.0423029  1.082629   0.1430766          0.1430222
# auc14 1.064482       1.0414105  1.082599   0.1430810          0.1430234
# auc15 1.066999       1.0466973  1.083480   0.1430677          0.1430192
# auc16 1.067595       1.0499660  1.085276   0.1430770          0.1430267
# auc17 1.066528       1.0452292  1.084921   0.1430743          0.1430222
# auc18 1.063849       1.0494544  1.082928   0.1430531          0.1430063
# auc19 1.064586       1.0489803  1.084539   0.1430569          0.1430128
#       brier_score_75
# auc   0.1445394
# auc1  0.1437014
# auc2  0.1435643
# auc3  0.1433998
# auc4  0.1433340
# auc5  0.1432812
# auc6  0.1432290
# auc7  0.1432401
# auc8  0.1431843
# auc9  0.1431934
# auc10 0.1431623
# auc11 0.1431495
# auc12 0.1431624
# auc13 0.1431496
# auc14 0.1431526
# auc15 0.1431412
# auc16 0.1431339
# auc17 0.1431303
# auc18 0.1430972
# auc19 0.1431133

# %%
# 设置图像输出宽度
options(repr.plot.width = 8, repr.plot.height = 8)
create_error_bar_plots(total_results_adjust_ss_3, "adjust sample size for event rate shift")
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
